# %% [markdown]
# ## Get Technologies
# This notbook has the goal to execte the method get_all_technologies from app_utils.py. The result should be copied and pasted into agent_tools.py by replacing the existing get_technologies method.
#
# ```python
#  allowed_technologies = 'YOUR LIST OF TECHNOLOGIES HERE'
# ```

# %%
import sys
from pathlib import Path

# Ajouter le chemin racine du projet au sys.path
project_root = Path(__file__).parent.parent if '__file__' in globals() else Path.cwd().parent
sys.path.insert(0, str(project_root))

# %%
import importlib
import app_utils
importlib.reload(app_utils)

from app_utils import get_all_technologies
get_all_technologies()
